# %%
# 매틀 플롯 그래프 그리는 방법은 크게 2 가지로 설명하고 있음
# 객체 기반 스타일로 그래프 그리기

# 1. 기본으로 그리기 = 기본으로 제공되는 기반으로 그리기
# 2. 객체기반으로 그리기 = 커스텀 마이징

# %%
import matplotlib.pyplot as plt

x = [ i for i in range(1,6)]
y = [ i for i in range(1,6)]

plt.plot(x,y)
plt.title("첫번째 그래프")
plt.xlabel("x축")
plt.ylabel("y축")

#plt.show()
# Out:
# Text(0, 0.5, 'y축')
# /usr/local/lib/python3.12/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 52629 (\N{HANGUL SYLLABLE CUG}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 52395 (\N{HANGUL SYLLABLE CEOS}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 48264 (\N{HANGUL SYLLABLE BEON}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 51704 (\N{HANGUL SYLLABLE JJAE}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 44536 (\N{HANGUL SYLLABLE GEU}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 47000 (\N{HANGUL SYLLABLE RAE}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 54532 (\N{HANGUL SYLLABLE PEU}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52629 (\N{HANGUL SYLLABLE CUG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52395 (\N{HANGUL SYLLABLE CEOS}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48264 (\N{HANGUL SYLLABLE BEON}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51704 (\N{HANGUL SYLLABLE JJAE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44536 (\N{HANGUL SYLLABLE GEU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47000 (\N{HANGUL SYLLABLE RAE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54532 (\N{HANGUL SYLLABLE PEU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# import matplotlib.pyplot as plt

# x = [ i for i in range(1,6)]
# y = [ i for i in range(1,6)]

# plt.plot(x,y)
# plt.title("첫번째 그래프")
# plt.xlabel("x축")
# plt.ylabel("y축")

# #plt.show() 


# 객체기반으로 그리기
# fig는 전체 스케치북 를 의미함
# ax는 그래프를 그릴 수 있는 도화지

x = [ 1,2,3,4,5]
y = [ 1,2,3,4,5]

fig, ax = plt.subplots()
ax.plot(x,y)
ax.set_xlabel("x축")
ax.set_ylabel("y축")

fig.set_dpi(300)
fig.savefig("first_plot.png")
# Out:
# /tmp/ipykernel_3364/3490086464.py:25: UserWarning: Glyph 52629 (\N{HANGUL SYLLABLE CUG}) missing from font(s) DejaVu Sans.
#   fig.savefig("first_plot.png")

# %%
# 1. Figure와  Axes 2개 생성 (1행 2열 구조)

fig , ax = plt.subplots(1,2,figsize=(10,4)) # 가로 10인치 세로 4인치
ax[0].plot([1,2,3,4],[1,2,3,4],color="blue",marker="o")
ax[0].set_title("first")
ax[0].set_xlabel("X axis")
ax[0].set_ylabel("Y axis")

ax[1].plot([1,2,3,4],[1,2,3,4],color="green",marker="x")
ax[1].set_title("first")
ax[1].set_xlabel('X-axis',loc="right",labelpad=15, fontdict={'family': 'serif', 'color': 'b', 'weight': 'bold', 'size': 14})
ax[1].set_ylabel("Y axis")
# Out:
# Text(0, 0.5, 'Y axis')

# %%
# 라벨 관련옵션

plt.plot([1,2,3,4],[1,4,6,9])
plt.xlabel('X-axis',loc="right",labelpad=15, fontdict={'family': 'serif', 'color': 'b', 'weight': 'bold', 'size': 14})
plt.ylabel('Y-axis',loc="top",labelpad=20, fontdict={'family': 'serif', 'color': 'r', 'weight': 'normal', 'size': "xx-large"})
# Out:
# Text(0, 1, 'Y-axis')

# %%
plt.plot([1,2,3,4],[1,4,6,9],label="price")

# 범례 위치 지정
#plt.legend(loc=(0.5,0.5))
plt.legend(loc="lower right")
