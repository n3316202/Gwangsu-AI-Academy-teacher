# %%
import pandas as pd

# 데이터 생성
scores = pd.Series([80, 82, 83, 84, 85, 86, 87, 88, 89, 90])

# 기본 통계
print(scores.describe())
# Out:
# count    10.000000
# mean     85.400000
# std       3.204164
# min      80.000000
# 25%      83.250000
# 50%      85.500000
# 75%      87.750000
# max      90.000000
# dtype: float64
