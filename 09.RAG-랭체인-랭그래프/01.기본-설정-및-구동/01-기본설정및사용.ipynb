# %%
# !pip install langchain langchain-openai langchain-anthropic langgraph
from openai import OpenAI

# %%
api_key = "sk-"
client = OpenAI(api_key=api_key)

reponse = client.responses.create(
    model="gpt-4o-mini",
    input="2022년 월드컴 우승팁은 어디야"
)

print(reponse.output_text)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# /tmp/ipykernel_5290/3065043487.py in <cell line: 0>()
#       2 client = OpenAI(api_key=api_key)
#       3
# ----> 4 reponse = client.responses.create(
#       5     model="gpt-4o-mini",
#       6     input="2022년 월드컴 우승팁은 어디야"
#
# /usr/local/lib/python3.12/dist-packages/openai/resources/responses/responses.py in create(self, background, context_management, conversation, include, input, instructions, max_output_tokens, max_tool_calls, metadata, model, moderation, parallel_tool_calls, previous_response_id, prompt, prompt_cache_key, prompt_cache_retention, reasoning, safety_identifier, service_tier, store, stream, stream_options, temperature, text, tool_choice, tools, top_logprobs, top_p, truncation, user, extra_headers, extra_query, extra_body, timeout)
# ...
