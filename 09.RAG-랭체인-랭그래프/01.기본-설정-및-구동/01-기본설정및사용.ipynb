# %%
# !pip install langchain langchain-openai langchain-anthropic langgraph
from openai import OpenAI

# %%
api_key = "sk-"
client = OpenAI(api_key=api_key)

reponse = client.responses.create(
    model="gpt-4o-mini",
    input="2022년 월드컴 우승팁은 어디야"
)

print(reponse.output_text)
# Out:
# 2022년 월드컵은 카타르에서 개최되었고, 아르헨티나가 우승했습니다. 아르헨티나는 결승에서 프랑스를 상대로 극적인 승부차기 끝에 우승컵을 들어 올렸습니다. 이 대회에서 아르헨티나는 리오넬 메시의 뛰어난 활약으로 많은 주목을 받았습니다. 월드컵과 관련된 더 자세한 정보나 특정 경기의 분석이 필요하시면 말씀해 주세요!
